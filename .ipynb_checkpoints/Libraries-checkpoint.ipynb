# %% [markdown]
# ScyPy for scientific and engineering applications.
# ====

# %%
from scipy.misc import imread, imsave, imresize

# %%
img = imread('assets/cat.jpg')
print(img.dtype, img.shape)
# Out:
# uint8 (900, 1200, 3)
# c:\users\kim\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
# image luminance scaling for each channel by using broadcasting.
img_tinted = img * [1, 0.95, 0.3]  # R은 그대로!, G, B를 변환
imsave('assets/cat_tinted.jpg', img_tinted)
# Out:
# c:\users\kim\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
img_resized = imresize(img_tinted, (300,300))
imsave('assets/cat_resized.jpg', img_resized)
# Out:
# c:\users\kim\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """Entry point for launching an IPython kernel.
# c:\users\kim\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.

# %% [markdown]
# Matplotlib for plotting.
# ====
# Refer the documentation for more details:
# <https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 3*np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title('Sine and Cosine')
plt.legend(['Sine', 'Cosine'])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 3*np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.subplot(2,1,1)
plt.plot(x, y_sin)
plt.title('Sine')

plt.subplot(2,1,2)
plt.plot(x, y_cos)
plt.title('Cosine')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 3*np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.subplot(1,2,1)
plt.plot(x, y_sin)
plt.title('Sine')

plt.subplot(1,2,2)
plt.plot(x, y_cos)
plt.title('Cosine')

plt.show()

# %%
import numpy as np
from scipy.misc import imread, imresize
import matplotlib.pyplot as plt

img = imread('assets/cat.jpg')
img_tinted = img * [1, 0.95, 0.9]

plt.subplot(1, 4, 1)
plt.imshow(img)

plt.subplot(1, 4, 2)
plt.imshow(img_tinted)

# 0~1일 경우 정상적으로 출력
plt.subplot(1, 4, 3)
plt.imshow(img_tinted/255)

# uint8을 사용해야 0~255로 정상적으로 출력
plt.subplot(1, 4, 4)
plt.imshow(np.uint8(img_tinted))
plt.show()
# Out:
# c:\users\kim\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """
